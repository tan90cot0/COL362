# %%
import matplotlib.pyplot as plt
  
# creating plotting data
xaxis =['9999-12-12']
yaxis =[0]
  
# plotting 
plt.plot(xaxis, yaxis)
plt.xlabel("Date")
plt.ylabel("Value")
  
# saving the file.Make sure you 
# use savefig() before show().
plt.savefig("india_cases.png")
